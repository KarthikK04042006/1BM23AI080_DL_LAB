# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

X = np.array([0.5, -1.2, 3.0])
weights = np.array([0.4, -0.6, 0.2])
bias = 0.1

z = np.dot(X, weights) + bias
z_values = np.linspace(z - 3, z + 3, 100)

sigmoid_output = sigmoid(z)
tanh_output = tanh(z)
relu_output = relu(z)

print(f"Activation: sigmoid, Output: {sigmoid_output:.4f}")
print(f"Activation: tanh, Output: {tanh_output:.4f}")
print(f"Activation: relu, Output: {relu_output:.4f}")

plt.figure(figsize=(6,4))
plt.plot(z_values, sigmoid(z_values), label='Sigmoid', color='black')
plt.scatter([z], [sigmoid_output], color='black')
plt.title('Sigmoid Activation')
plt.xlabel('Weighted Sum (z)')
plt.ylabel('Output')
plt.grid(True)
plt.show()

plt.figure(figsize=(6,4))
plt.plot(z_values, tanh(z_values), label='Tanh', color='red')
plt.scatter([z], [tanh_output], color='red')
plt.title('Tanh Activation')
plt.xlabel('Weighted Sum (z)')
plt.ylabel('Output')
plt.grid(True)
plt.show()

plt.figure(figsize=(6,4))
plt.plot(z_values, relu(z_values), label='ReLU', color='yellow')
plt.scatter([z], [relu_output], color='yellow')
plt.title('ReLU Activation')
plt.xlabel('Weighted Sum (z)')
plt.ylabel('Output')
plt.grid(True)
plt.show()
# Out:
# Activation: sigmoid, Output: 0.8348
# Activation: tanh, Output: 0.9246
# Activation: relu, Output: 1.6200

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

class Neuron:
    def __init__(self, n_inputs, activation='sigmoid'):
        self.weights = np.random.randn(n_inputs)
        self.bias = np.random.randn()
        self.activation = activation

    def activate(self, x):
        z = np.dot(x, self.weights) + self.bias
        if self.activation == 'sigmoid':
            return sigmoid(z)
        elif self.activation == 'tanh':
            return tanh(z)
        elif self.activation == 'relu':
            return relu(z)
        else:
            return z

X = np.array([0.5, -1.2, 3.0])
weights = [0.4,-0.6,0.2]
bias = 0.1

for act in ['sigmoid', 'tanh', 'relu']:
    neuron = Neuron(len(X), activation=act)
    output = neuron.activate(X)
    print(f"Activation: {act:.7s}, Output: {output:.4f}")
# Out:
# Activation: sigmoid, Output: 0.0341
# Activation: tanh, Output: 0.8976
# Activation: relu, Output: 0.0000
